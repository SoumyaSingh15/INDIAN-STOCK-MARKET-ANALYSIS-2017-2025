# %% [markdown]
# #                                                Descriptive Analysis Project

# %% [markdown]
# ## *Data Visionaries*
# ### Shreya Mohanta & Soumya Singh

# %% [markdown]
# ## Stock Price Trend, Return, and Volatility Analysis in the Indian Market

# %% [markdown]
# #### The Indian stock market experiences frequent fluctuations, making it diﬃcult for investors to understand price trends, compare returns,
# #### and assess market risk. This project analyzes the stock price trend of a selected company, compares returns of companies, and
# #### examines the volatility of major index like NIFTY using historical data to support better investment decisions.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Company tickers
tickers = {
    "Reliance": "RELIANCE.NS",
    "HDFC": "HDFCBANK.NS",
    "ITC": "ITC.NS",
    "Maruti Suzuki": "MARUTI.NS"
}

start_date = "2017-01-01"
end_date = "2026-01-01"

stock_data = {}

for company, ticker in tickers.items():
    data = yf.download(
        ticker,
        start=start_date,
        end=end_date,
        interval="1mo"
    )
    stock_data[company] = data
    print(f"{company} monthly data downloaded")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Reliance monthly data downloaded
# HDFC monthly data downloaded
# ITC monthly data downloaded
# Maruti Suzuki monthly data downloaded

# %%
# Reliance Communications (RCOM) ticker
tickers = {
    "Reliance Communications": "RCOM.NS"
}

start_date = "2017-01-01"
end_date = "2025-03-05"  # Last trading date (2025-03-04)

stock_data1 = {}

for company, ticker in tickers.items():
    data = yf.download(
        ticker,
        start=start_date,
        end=end_date,
        interval="1mo" 
    )
    stock_data1[company] = data
    print(f"{company} monthly data downloaded")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Reliance Communications monthly data downloaded

# %%
# Ballarpur Industries (BIL) ticker
tickers = {
    "Ballarpur Industries": "BIL.NS"
}

start_date = "2017-01-01"
end_date = "2023-06-23"  # Last trading date of old stock (2023-06-22)

stock_data2 = {}

for company, ticker in tickers.items():
    data = yf.download(
        ticker,
        start=start_date,
        end=end_date,
        interval="1mo"
    )
    stock_data2[company] = data
    print(f"{company} monthly data downloaded")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ballarpur Industries monthly data downloaded

# %%
stock_data["Reliance"].shape
# Out:
# (108, 5)

# %%
stock_data["HDFC"].shape
# Out:
# (108, 5)

# %%
stock_data["ITC"].shape
# Out:
# (108, 5)

# %%
stock_data["Maruti Suzuki"].shape
# Out:
# (108, 5)

# %%
stock_data1["Reliance Communications"].shape
# Out:
# (99, 5)

# %%
stock_data2["Ballarpur Industries"].shape
# Out:
# (78, 5)

# %%
stock_data["Reliance"].columns
# Out:
# MultiIndex([( 'Close', 'RELIANCE.NS'),
#             (  'High', 'RELIANCE.NS'),
#             (   'Low', 'RELIANCE.NS'),
#             (  'Open', 'RELIANCE.NS'),
#             ('Volume', 'RELIANCE.NS')],
#            names=['Price', 'Ticker'])

# %%
stock_data["HDFC"].columns
# Out:
# MultiIndex([( 'Close', 'HDFCBANK.NS'),
#             (  'High', 'HDFCBANK.NS'),
#             (   'Low', 'HDFCBANK.NS'),
#             (  'Open', 'HDFCBANK.NS'),
#             ('Volume', 'HDFCBANK.NS')],
#            names=['Price', 'Ticker'])

# %%
stock_data["ITC"].columns
# Out:
# MultiIndex([( 'Close', 'ITC.NS'),
#             (  'High', 'ITC.NS'),
#             (   'Low', 'ITC.NS'),
#             (  'Open', 'ITC.NS'),
#             ('Volume', 'ITC.NS')],
#            names=['Price', 'Ticker'])

# %%
stock_data["Maruti Suzuki"].columns
# Out:
# MultiIndex([( 'Close', 'MARUTI.NS'),
#             (  'High', 'MARUTI.NS'),
#             (   'Low', 'MARUTI.NS'),
#             (  'Open', 'MARUTI.NS'),
#             ('Volume', 'MARUTI.NS')],
#            names=['Price', 'Ticker'])

# %%
stock_data1["Reliance Communications"].columns
# Out:
# MultiIndex([( 'Close', 'RCOM.NS'),
#             (  'High', 'RCOM.NS'),
#             (   'Low', 'RCOM.NS'),
#             (  'Open', 'RCOM.NS'),
#             ('Volume', 'RCOM.NS')],
#            names=['Price', 'Ticker'])

# %%
stock_data2["Ballarpur Industries"].columns
# Out:
# MultiIndex([( 'Close', 'BIL.NS'),
#             (  'High', 'BIL.NS'),
#             (   'Low', 'BIL.NS'),
#             (  'Open', 'BIL.NS'),
#             ('Volume', 'BIL.NS')],
#            names=['Price', 'Ticker'])

# %%
stock_data["Reliance"].isnull().sum()
# Out:
# Price   Ticker
# Close   RELIANCE.NS    0
# High    RELIANCE.NS    0
# Low     RELIANCE.NS    0
# Open    RELIANCE.NS    0
# Volume  RELIANCE.NS    0
# dtype: int64

# %%
stock_data["HDFC"].isnull().sum()
# Out:
# Price   Ticker
# Close   HDFCBANK.NS    0
# High    HDFCBANK.NS    0
# Low     HDFCBANK.NS    0
# Open    HDFCBANK.NS    0
# Volume  HDFCBANK.NS    0
# dtype: int64

# %%
stock_data["ITC"].isnull().sum()
# Out:
# Price   Ticker
# Close   ITC.NS    0
# High    ITC.NS    0
# Low     ITC.NS    0
# Open    ITC.NS    0
# Volume  ITC.NS    0
# dtype: int64

# %%
stock_data["Maruti Suzuki"].isnull().sum()
# Out:
# Price   Ticker
# Close   MARUTI.NS    0
# High    MARUTI.NS    0
# Low     MARUTI.NS    0
# Open    MARUTI.NS    0
# Volume  MARUTI.NS    0
# dtype: int64

# %%
stock_data1["Reliance Communications"].isnull().sum()
# Out:
# Price   Ticker
# Close   RCOM.NS    0
# High    RCOM.NS    0
# Low     RCOM.NS    0
# Open    RCOM.NS    0
# Volume  RCOM.NS    0
# dtype: int64

# %%
stock_data2["Ballarpur Industries"].isnull().sum()
# Out:
# Price   Ticker
# Close   BIL.NS    0
# High    BIL.NS    0
# Low     BIL.NS    0
# Open    BIL.NS    0
# Volume  BIL.NS    0
# dtype: int64
